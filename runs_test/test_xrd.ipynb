# %%
import phd_parser as pp
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

# %%
MOCK_FILE_PATH = Path(r"..\tests\xrd\xrd_mock_e1290.xy")

# %%
xrd_raw = pp.xrd.XRDData.from_e1290(MOCK_FILE_PATH)
xrd_raw
# Out:
# XRDData(shape={'angle': 8243}, 2θ=5.000–90.001 °)

# %%
xrd = xrd_raw.select_angle_range(20, 80).smooth_savgol(window_length=11, polyorder=3)

# %%
fig, ax = plt.subplots()
ax.plot(xrd.angle, xrd.values)
