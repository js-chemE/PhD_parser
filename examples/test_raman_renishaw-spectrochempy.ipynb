# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# In C:\Users\jsommer1\.matplotlib\stylelib\scpy.mplstyle: The text.hinting_factor rcParam was deprecated in Matplotlib 3.11 and will be removed in 3.13.
# In C:\Users\jsommer1\.matplotlib\stylelib\scpy.mplstyle: The text.kerning_factor rcParam was deprecated in Matplotlib 3.11 and will be removed in 3.13.

# %%
fig, ax = plt.subplots()
ax.plot(np.sin(np.arange(0, 10, 0.1)))
plt.show()

# %%
import spectrochempy as scp

# %%
fig, ax = plt.subplots()
ax.plot(np.sin(np.arange(0, 10, 0.1)))
plt.show()

# %%
scp_raman = scp.read_wdf()
scp_raman
# Out:
# <style>/* SpectroChemPy output styling */
# .scp-output {
#     display: flex;
#     flex-direction: column;
#     gap: 2px;
# }
#
# .scp-output details {
#     padding: 1px;
# }
#
# .scp-output summary {
#     cursor: pointer;
#     font-weight: normal;
#     /*bold;*/
#     font-size: 11pt;
# }
#
# .scp-output summary:hover {
#     color: #888;
# }
#
# /* Parameters display styling */
# .scp-output .section {
#     display: flex;
#     flex-direction: row;
#     gap: 2px;
#     font-family: Arial, sans-serif;
#     font-size: 10pt;
#     margin-left: 15px;
# }
#
# .scp-output .meta-name,
# .scp-output .attr-name {
#     font-weight: 500;
#     color: #28A745;
#     text-align: right;
# }
#
# .scp-output .attr-name {
#     min-width: 100px;
# }
#
# .scp-output .meta-name {
#     min-width: 150px;
# }
#
# .scp-output .meta-value,
# .scp-output .attr-value {
#     flex: 1;
# }
#
# .scp-output .numeric {
#     color: #2D7FF9;
#     margin-left: 120px;
#     font-size: 10pt;
# }
#
# ...

# %%
fig, ax = plt.subplots()
ax.plot(np.sin(np.arange(0, 10, 0.1)))
plt.show()

# %%
scp.show_versions()
# Out:
# SYSTEM INFO
# ...
# - commit          None
# - python          3.13.7 (tags/v3.13.7:bcee1c3, Aug 14 2025, 14:15:11) [MSC v.1944 64 bit (AMD64)]
# - python-bits     64
# - OS              Windows
# - OS-release      11
# - machine         AMD64
# - processor       Intel64 Family 6 Model 186 Stepping 3, GenuineIntel
# - byteorder       little
# - LC_ALL          None
# - LANG            None
# - LOCALE          ('en_US', 'ISO8859-1')
#
# ENVIRONMENT INFO
# ...
# - type            venv
# - name            C:\Users\jsommer1\CODE\PhD_parser\.venv
# - prefix          c:\Users\jsommer1\CODE\PhD_parser\.venv
#
# SPECTROCHEMPY
# ...
# - version       0.11.0
#
# INSTALLED PACKAGES
# ...
#
# Dependencies
# ------------
# Package              Required                  Installed
# ..............................................................
#
# ---- core ----
# colorama             Any                       0.4.6
# dill                 Any                       0.4.1
# ...
