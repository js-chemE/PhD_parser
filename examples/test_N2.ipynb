# %%
import phd_parser as pp
from pathlib import Path

# %%
sample_path = Path(r"C:\Users\jsommer1\CODE\PhD_parser\tests\physisorption\tristar\2026-N-198.XLS")

# %%
rep = pp.physisorption.tristar.read_export(sample_path)

# %%
rep.keys()
# Out:
# dict_keys(['data', 'bet', 'meta'])

# %%
rep["meta"]
# Out:
# {'header': {'scalars': {'Sample': 'SK1003',
#    'Operator': 'Ivan',
#    'Sample owner': 'Ivan',
#    'File': 'D:\\TriStars\\Data2026\\2026-N-198.SMP',
#    'Started': Timestamp('2026-06-17 10:45:06'),
#    'Completed': Timestamp('2026-06-17 21:32:06'),
#    'Report time': Timestamp('2026-06-18 09:47:49'),
#    'Sample mass': {'value': 0.0944, 'unit': 'g'},
#    'Cold free space': {'value': 19.6175, 'unit': 'cm³'},
#    'Low pressure dose': None,
#    'Automatic degas': True},
#   'table': {'columns': ['Sample prep:  Stage',
#     'Temperature (K)',
#     'Ramp Rate (K/min)',
#     'Time (min)'],
#    'rows': [['1', '298', ' 5', '    2'],
#     ['2', '363', ' 5', '   60'],
#     ['3', '423', ' 5', '  900']]},
#   'notes': ['Micromeritics Instrument Corporation']},
#  'summary': {'scalars': {},
#   'table': None,
#   'notes': ['No summary reports could be produced.']},
#  'analyses': {'isotherm': {'report': {'scalars': {},
#     'table': {'columns': ['Relative Pressure (P/Po)',
# ...

# %%
rep["bet"]['surface_area_error']
# Out:
# 0.4825

# %%
n2 = pp.physisorption.PhysisorptionData.from_tristar_xls(sample_path)
n2
# Out:
# PhysisorptionData(ads=64 pts, des=52 pts, BET=105.11 m²/g)
